# %% [markdown]
# # Web Scraping
#
#
# Lesson Goals
#
#     Learn the basics of scraping content from web pages.
#     Perform scraping of text from a web page.
#     Perform extraction of an HTML table from a web page into a Pandas data frame.
#
# Introduction
#
# Web scraping refers to the automatic extraction of information from a web page. This information is often a page's content, but it can also include information in the page's headers, links present on the page, or any other information embedded in the page's HTML. Because of this, scraping has become one of the most popular ways to extract data from the web. With basic knowledge of HTML and the help of a few Python libraries, you can obtain information from just about any page on the internet.
#
# In this lesson, we will cover the basics of web scraping with Python and show examples of how to scrape text content from a simple web page as well the more complex task of extracting data from an HTML table embedded on a web page.
# Scraping a Simple Web Page
#
# Scraping a simple website is relatively straightforward. The first thing we need to do is determine the web page we want to scrape and the information we would like to obtain from it. For our purposes, let's suppose we wanted to scrape a Reuters news article and we wanted to extract the main text content (article title, story, etc.).
#
# We first need to specify the URL of the page we want to scrape and then use the requests library's get method to request the page and the content method to retrieve the HTML content.

# %%
import requests

url = 'https://www.reuters.com/article/us-shazam-m-a-apple-eu/eu-clears-apples-purchase-of-shazam-idUSKCN1LM1TZ'
html = requests.get(url).content
html[0:600]
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="x-dns-prefetch-control" content="on"/><meta name="robots" content="index, follow"/><meta name="twitter:site" content="@Reuters"/><meta name="twitter:creator" content="@Reuters"/><meta name="twitter:card" content="summary_large_image"/><meta name="msapplication-TileColor" content="#ff8000"/><meta name="msapplication-config" content="none"/><meta name="theme-color" content="#ffffff"/><meta property="article:publish'

# %% [markdown]
# As you can see, there is a lot of extra information here that we don't really need if all we are interested in is the text content from the page. We will need to perform a few steps to clean this up, the first of which is to use the BeautifulSoup library to read the raw HTML and structure it in a way where we will be able to more easily parse the information we want out of it. In BeautifulSoup terms, this is called "making the soup."

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta content="width=device-width" name="viewport"/><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="on" http-equiv="x-dns-prefetch-control"/><meta content="index, follow" name="robots"/><meta content="@Reuters" name="twitter:site"/><meta content="@Reuters" name="twitter:creator"/><meta content="summary_large_image" name="twitter:card"/><meta content="#ff8000" name="msapplication-TileColor"/><meta content="none" name="msapplication-config"/><meta content="#ffffff" name="theme-color"/><meta content="https://www.facebook.com/Reuters" property="article:publisher"/><link href="//s1.reutersmedia.net" rel="dns-prefetch"/><link href="//s2.reutersmedia.net" rel="dns-prefetch"/><link href="//s3.reutersmedia.net" rel="dns-prefetch"/><link href="//s4.reutersmedia.net" rel="dns-prefetch"/><link href="//static.reuters.com" rel="dns-prefetch"/><link href="//www.googletagservices.com" rel="dns-prefetch"/><link href="//www.googletagmanager.com" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//static.chartbeat.com" rel="dns-prefetch"/><link href="https://plus.google.com/+Reuters" rel="publisher"/><link href="/article/_next/static/images/favicon-9d0324f5d28e80e699a4e92617ab6f30.ico" rel="shortcut icon" type="image/x-icon"/><link href="/article/_next/static/images/favicon-16x16-e88bf4a1cca78d8c9db77bee8317e193.png" rel="icon" sizes="16x16" type="image/png"/><link href="/article/_next/static/images/favicon-32x32-410cb61c32b1ef3ab7c27530775eda36.png" rel="icon" sizes="32x32" type="image/png"/><link href="/article/_next/static/images/favicon-96x96-bda7fa3986384763dbb5a5486903d05b.png" rel="icon" sizes="96x96" type="image/png"/><link href="/article/_next/static/images/favicon-128x128-9de93d21fd227b42b54c84e4ab242504.png" rel="icon" sizes="128x128" type="image/png"/><link href="/article/_next/static/images/favicon-196x196-052cc719f1ac872e3544e51801338b46.png" rel="icon" sizes="196x196" type="image/png"/><meta content="The European Union approved Apple's planned acquisition of British music discovery app Shazam on Thursday, saying an EU antitrust investigation showed it would not harm competition in the bloc." name="description"/><meta content="Reuters Staff" name="author"/><meta content="US,SHAZAM,M,A,APPLE,EU,Anti-competitive Behavior,EU Institutions,Company News,Arts / Culture / Entertainment,European Union,Europe,United Kingdom,Antitrust Regulation,Mergers / Acquisitions / Takeovers,Music,Pictures,Online Services (NEC) (TRBC level 5),Phones &amp; Smart Phones (TRBC level 5),Picture Available,Music, Music Video Production &amp; Distribution (TRBC level 5),Corporate / Market Regulation,Entertainment Production (TRBC level 4),Software (TRBC level 4),Software &amp; IT Services (TRBC level 3),International Trade,United States,Western Europe" name="keywords"/><meta content="US;SHAZAM;M;A;APPLE;EU;Anti-competitive Behavior;EU Institutions;Company News;Arts / Culture / Entertainment;European Union;Europe;United Kingdom;Antitrust Regulation;Mergers / Acquisitions / Takeovers;Music;Pictures;Online Services (NEC) (TRBC level 5);Phones &amp; Smart Phones (TRBC level 5);Picture Available;Music, Music Video Production &amp; Distribution (TRBC level 5);Corporate / Market Regulation;Entertainment Production (TRBC level 4);Software (TRBC level 4);Software &amp; IT Services (TRBC level 3);International Trade;United States;Western Europe" name="news_keywords"/><meta content="2018-09-06T17:21:38Z" name="REVISION_DATE"/><meta content="2018-09-06T17:21:38Z" name="analyticsAttributes.articleDate"/><meta content="Reuters Staff" name="analyticsAttributes.author"/><meta content="https://www.reuters.com/article/us-shazam-m-a-apple-eu-idUSKCN1LM1TZ" name="analyticsAttributes.canonicalUrl"/><meta content="EU clears Apple's purchase of Shazam" name="analyticsAttributes.contentTitle"/><meta content="us" name="analyticsAttributes.edition"/><meta content="US,SHAZAM,M,A,AP ...
# }}();</script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#    new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#    j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#    'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#    })(window,document,'script','dataLayer','GTM-W9SLGS');</script><script>function gtag() {dataLayer.push(arguments)}</script><title>EU clears Apple's purchase of Shazam | Reuters</title><meta content="988502044532272" property="fb:app_id"/><meta content="114050161948682" property="fb:pages"/><script data-admantx-url="https://www.reuters.com/article/us-shazam-m-a-apple-eu/eu-clears-apples-purchase-of-shazam-idUSKCN1LM1TZ" data-dartzone="/4735792/reuters.com/business/legal/article" data-edition="us" data-evidon-consent-cookie-reset-date="2020-10-25" data-onetrust-script-version="prod" data-privacy-domain="reuters.com" id="bootstrap" src="/article/_next/static/scripts/bootstrap-b373671d16faf7e59703005baa716f1b.js"></script><meta content="85" name="next-head-count"/><link as="style" href="/article/_next/static/css/pages/_app.b3cdf4b1.chunk.css" rel="preload"/><link data-n-g="" href="/article/_next/static/css/pages/_app.b3cdf4b1.chunk.css" rel="stylesheet"/><link as="style" href="/article/_next/static/css/pages/ArticlePage.4128d115.chunk.css" rel="preload"/><link data-n-p="" href="/article/_next/static/css/pages/ArticlePage.4128d115.chunk.css" rel="stylesheet"/><noscript data-n-css="true"></noscript><link as="script" href="/article/_next/static/chunks/main-faf9b40598099c5c92e1.js" rel="preload"/><link as="script" href="/article/_next/static/chunks/webpack-18ac7c7581076d37e334.js" rel="preload"/><link as="script" href="/article/_next/static/chunks/pages/_app-6207597398b10a982c33.js" rel="preload"/><link as="script" href="/article/_next/static/chunks/pages/ArticlePage-4033bea442861f8dd9b9.js" rel="preload"/></head><body dir="ltr"><div id="__next"><div><div class="TwoColumnsLayout-header-1_PU9"><header class="Header__header___1JYoe"><div class="Header__global-utility___3HJ1Z"><div class="GlobalUtility__container___wT9CD"><button aria-expanded="false" aria-labelledby="global-utility-dropdown-label" class="Dropdown__toggle___2c6Sb GlobalUtility__more-button___2rDc3" type="button"><p class="TextLabel__text-label___3oCVw TextLabel__gray___1V4fk TextLabel__regular___2X0ym GlobalUtility__label___35new" id="global-utility-dropdown-label">Discover Thomson Reuters</p><svg class="GlobalUtility__ellipsis___23H77" viewbox="0 0 13 3" xmlns="http://www.w3.org/2000/svg"><circle cx="1.5" cy="1.5" r="1.5"></circle><circle cx="6.5" cy="1.5" r="1.5"></circle><circle cx="11.5" cy="1.5" r="1.5"></circle></svg></button><div class="GlobalUtility__utility-buttons___1dPIU"><a class="TextLabel__text-label___3oCVw TextLabel__gray___1V4fk TextLabel__regular___2X0ym GlobalUtility__label___35new" href="https://www.thomsonreuters.com/en/global-gateway.html">Directory of sites</a><a class="TextLabel__text-label___3oCVw TextLabel__gray___1V4fk TextLabel__regular___2X0ym GlobalUtility__label___35new" href="https://www.thomsonreuters.com/en/login.html">Login</a><a class="TextLabel__text-label___3oCVw TextLabel__gray___1V4fk TextLabel__regular___2X0ym GlobalUtility__label___35new" href="https://reuters.zendesk.com/hc/en-us/articles/216467423-Contact-Reuters">Contact</a><a class="TextLabel__text-label___3oCVw TextLabel__gray___1V4fk TextLabel__regular___2X0ym GlobalUtility__label___35new" href="https://reuters.zendesk.com/hc/en-us">Support</a></div></div></div><div class="BreakpointDetector__container___2fuT_"><span class="BreakpointDetector__for-phone-only___4_LFl" data-name="for-phone-only">for-phone-only</span><span class="BreakpointDetector__for-tablet-portrait-up___3JyHf" data-name="for-tablet-portrait-up">for-tablet-portrait-up</span><span class="BreakpointDetector__for-tablet-landscape-up___1WuSv" data-name="for-tablet-landscape-up">for-tablet-landscape-up</span><span class="BreakpointDetector__for-desktop-up___3y1_j" data-name="for-desktop-up">for-desktop-up</span><span class="BreakpointDetector__for-wide-desktop-up___1ZVju" data-name="for-wide-desktop-up">for-wide-desktop-up</span></div></header></div><div class="TwoColumnsLayout-leaderboard-26t3U"></div><div c ...
# L(9225,f,!0)}}},function(){L(9225,f,!1)})}function g(u,f,t){if(v.jfvgw4e2Mobile){var n=w[""+p(Qv(p("V1o8bGRae29bM0lWWUhZUlVJPEhkWkl4ZTU0c1s0Z1ZUWUVUVVlMQA=="),-3))];n?f(n,!u,!1,v.jfvgw7cfRnd):t(5588,!u,!1)}else t(5588,!u,!1)}function l(u,f,w,n){w||dv(Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@94)p@35)g@53493848)w@5)l@4<86555:75)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJF"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),function(){if(!w){w=!0;var e=this;if(e.height<2)return void L(5588,f,!1);if(n==v.jfvgw7cfRnd){var g=u,l=_("div");t[""+p(Qv(p("V1o8bGRae29bM0lWWUhZUlVJPEhkWkl4ZTU0cw=="),-3))]=l,lv(l,"bVDEVPu");var r=e;v.jfvgwaf6Am[5588]&&(y(v.jfvgwaf6Am[5588]),v.jfvgwaf6Am[5588]=!1),h(r,function(u,f){if(!v.jfvgw628Pc[5588]){u.preventDefault(),u.stopPropagation();for(var f=i(u,this),t=0;t<v.jfvgw5f1Oc.length;t++){var w=v.jfvgw5f1Oc[t];if(5588==w.p&&f.x>=w.x&&f.x<w.x+w.w&&f.y>=w.y&&f.y<w.y+w.h){if(w.u){var n=w.t.length>0?w.t:"_self";n=0==u.button&&u.ctrlKey?"_blank":n,jv(v,w.u,w.u,n,!0)}return}}var h=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;4)p@35)g@53483955)w@5)l@767955:944)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJZ"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@47)p@35)g@534;3753)w@5)l@;<:57974:8)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJP"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@93)p@35)g@534:4537)w@5)l@;59774;<6:)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ\\"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@83)p@35)g@534;393:)w@5)l@<<696577;<)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJE"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;4)p@35)g@53483:5;)w@5)l@<9<:;47<;6)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJY"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],e=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@9<)p@35)g@5349374<)w@5)l@8;;8558465)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJU"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@58)p@35)g@534;4447)w@5)l@6<<;747<88)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJE"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@9<)p@35)g@534;4449)w@5)l@4:87<5;;54)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJX"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;3)p@35)g@53493736)w@5)l@78:9994939)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJT"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@68)p@35)g@534;3<37)w@5)l@4456963<67)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJV"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],g=h[1*o(5*f.y/this.offsetHeight)+o(1*f.x/this.offsetWidth)],l=e[1*o(5*f.y/this.offsetHeight)+o(1*f.x/this.offsetWidth)];jv(v,g,l,"_blank")}}),$(l,e),$(g,l),v.jfvgwdeb54.a[5588]=l;var s=_("div");Y(s,""+p(Qv(p("U0pVc2dsRW1lSkl9Zn0zbGdKejhSR011UkpUbFNsRDtPNVVzZ203alNKVXNnbEVtZUpJfWZ9M2xVV2o4ZHBUOGRwWGxTbEQ7TzVVc2dtN2pTSlVzZ2xFbWVKSX1mfTNsWG1FbFF9an1dSnJsU2xEO081VXNnbTdqU0tRelxaN2pcNXtrZjZQPExvTHpcbWY3UDVVdExtN2pTRjx9ZkpJeFNqQEA="),-3))),pv(s.childNodes,function(u,f){iv(l,f),v.jfvgwCln.push(f)}),v.jfvgwCln.push(s);var s=_("div");Y(s,""+p(Qv(p("U0pVc2dsRW1lSkl9Zn0zbGR9ajZQbklGZm1uamVKTTNlbVQ0XDZybFNsRDtPNVVzZ203QA=="),-3))),pv(s.childNodes,function(u,f){hv(l,f),v.jfvgwCln.push(f)}),v.jfvgwCln.push(s),Bv(l,5588,Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@59)p@35)g@53483539)w@5)l@<98896585:)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJI"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)),L(5588,f,!0)}}},function(){L(5588,f,!1)})}function r(u,t,w){if(v.jfvgw4e2Mobile){var n=f(""+p(Qv(p("TDVVemY1e3lnSTxwXVpZbg=="),-3)),"^^");n?t(n,!u,!1,v.jfvgw7cfRnd):w(9234,!u,!1)}else w(9234,!u,!1)}function s(u,f,w,n){w||dv(Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@<5)p@35)g@534:365<)w@5)l@8934645;7;)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJW"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),fun ...
# var h=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@:7)p@35)g@534;455;)w@5)l@558675;3;6)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJZ"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@4:)p@35)g@534:4448)w@5)l@943836389:)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJJ"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@48)p@35)g@534:454:)w@5)l@:;96;64;:<)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJX"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@79)p@35)g@5349374<)w@5)l@:4996444;<)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ]"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@95)p@35)g@5349355;)w@5)l@6438<598<9)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJW"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@<8)p@35)g@534:354;)w@5)l@;476568<:;)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJY"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],e=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@65)p@35)g@53493638)w@5)l@;8;46676:3)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJR"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@47)p@35)g@5348454<)w@5)l@486;<4;364)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJS"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@84)p@35)g@53483856)w@5)l@7<34<66883)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJX"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@48)p@35)g@53493<59)w@5)l@;778463:;:)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ]"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@78)p@35)g@53493<58)w@5)l@7<;3<4<<83)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJI"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@7;)p@35)g@53493;53)w@5)l@;47:364<85)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJR"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],g=h[1*o(6*f.y/this.offsetHeight)+o(1*f.x/this.offsetWidth)],l=e[1*o(6*f.y/this.offsetHeight)+o(1*f.x/this.offsetWidth)];jv(v,g,l,"_blank")}}),$(l,e),$(g,l),v.jfvgwdeb54.a[6995]=l,V([{function:function(v,u){var f=_("div");vv(f,"class","k872ABr9 uzq982mp"),Ov(v,"beforeEnd",f)}},{function:function(u,f){function t(){var u=v.jfvgwdeb54&&v.jfvgwdeb54.w&&v.jfvgwdeb54.w[6999],f=v.jfvgwdeb54&&v.jfvgwdeb54.a&&v.jfvgwdeb54.a[6995],n=v.jfvgwdeb54&&v.jfvgwdeb54.a&&v.jfvgwdeb54.a[7e3];f&&n&&u&&(v.jfvgwLoc!==location.pathname&&(v.jfvgwLoc=location.pathname,!1===v.jfvgwStat?(v.jfvgwStat=!v.jfvgwStat,uv(f,"display","none",""),uv(n,"display","initial",""),$(u,n)):(v.jfvgwStat=!v.jfvgwStat,uv(f,"display",null),uv(n,"display",null),$(u,f)),w(u,t)),v[p("cmVxdWVzdEFuaW1hdGlvbkZyYW1l")](t))}var w=function(u,f){var t=setInterval(function(){var w=rv("[class^=ThreeColumnsLayout-right-column] > [class^='AdSlot__container'] > :first-child, [class^=TwoColumnsLayout-right] > [class^=RightRail] [class^='AdSlot__container'] > :first-child[id*=mpu]");u&&w&&w.parentElement&&(w.parentElement.insertBefore(u,w),clearInterval(t),v[p("cmVxdWVzdEFuaW1hdGlvbkZyYW1l")](f))},100)};v.jfvgwLoc=location.pathname,v.jfvgwStat=!1,v[p("cmVxdWVzdEFuaW1hdGlvbkZyYW1l")](t)}}],l,6995),Bv(l,6995,Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;7)p@35)g@534:343;)w@5)l@96:;3855;6)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJY"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)),L(6995,f,!0)}}},function(){L(6995,f,!1)})}function Q(u,f,w,n){w||dv(Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@94)p@35)g@53493954)w@5)l@8<<<57;;58)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJQ"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),function(){if(!w){w=!0;var e=this;if(e.height<2)return void L(7e3,f,!1);if(n==v.jfvgw7cfRnd){var g=u,l=_("div");t[""+p(Qv(p("V1lNaVlKPHpbM1FrZ0pZcWU2TThbM0x8"),-3))]=l,lv(l,"NvYhAMFgrn");var r=e;v.jfvgwaf6Am[7e3]&&(y(v.jfvgwaf6Am[7e3]),v.jfvgwaf6Am[7e3]=!1),h(r,function(u,f){i ...
# var h=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@58)p@35)g@53483763)w@5)l@968475<<:8)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJS"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@59)p@35)g@53484337)w@5)l@78::;4<6:4)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJN"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],e=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@54)p@35)g@534;435;)w@5)l@473;743566)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJU"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;:)p@35)g@5348393:)w@5)l@6368<574;5)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJW"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],g=h[2*o(1*f.y/this.offsetHeight)+o(2*f.x/this.offsetWidth)],l=e[2*o(1*f.y/this.offsetHeight)+o(2*f.x/this.offsetWidth)];jv(v,g,l,"_blank")}}),$(l,e),$(g,l),v.jfvgwdeb54.a[6247]=l,v.jfvgwCln.push(l),Bv(l,6247,Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@44)p@35)g@5348344:)w@5)l@7:;458<865)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJX"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)),L(6247,f,!0)}}},function(){L(6247,f,!1)})}function K(u,t,w){var n=f(""+p(Qv(p("TmxELkxKVXNnbDh9XXBNeVxwcjY="),-3)),"");n?t(n,!u,!1,v.jfvgw7cfRnd):w(6248,!u,!1)}function fv(u,f,w,n){w||dv(Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@96)p@35)g@53493<34)w@5)l@78<:<86489)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJH"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),function(){if(!w){w=!0;var e=this;if(e.height<2)return void L(6248,f,!1);if(n==v.jfvgw7cfRnd){var g=u,l=_("div");t[""+p(Qv(p("WDM0RVhvVUpVWFlIWzNVc1xaOHllWm9pUEdqd1BXREA="),-3))]=l,lv(l,"XkPbJJ");var r=e;v.jfvgwaf6Am[6248]&&(y(v.jfvgwaf6Am[6248]),v.jfvgwaf6Am[6248]=!1),h(r,function(u,f){if(!v.jfvgw628Pc[6248]){u.preventDefault(),u.stopPropagation();for(var f=i(u,this),t=0;t<v.jfvgw5f1Oc.length;t++){var w=v.jfvgw5f1Oc[t];if(6248==w.p&&f.x>=w.x&&f.x<w.x+w.w&&f.y>=w.y&&f.y<w.y+w.h){if(w.u){var n=w.t.length>0?w.t:"_self";n=0==u.button&&u.ctrlKey?"_blank":n,jv(v,w.u,w.u,n,!0)}return}}var h=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@68)p@35)g@534;3839)w@5)l@958494;63;)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ["+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@:6)p@35)g@53483;48)w@5)l@564:645685)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJH"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@:;)p@35)g@53483;64)w@5)l@:974:5:85;)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJZ"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],e=[Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@4<)p@35)g@53483<46)w@5)l@:39644<<59)z@6;3)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJE"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@93)p@35)g@5348385<)w@5)l@65:7446574)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ\\"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@94)p@35)g@534;3856)w@5)l@:946<53449)z@633)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJI"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)],g=h[3*o(1*f.y/this.offsetHeight)+o(3*f.x/this.offsetWidth)],l=e[3*o(1*f.y/this.offsetHeight)+o(3*f.x/this.offsetWidth)];jv(v,g,l,"_blank")}}),$(l,e),$(g,l),v.jfvgwdeb54.a[6248]=l,v.jfvgwCln.push(l),Bv(l,6248,Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@;3)p@35)g@534:3638)w@5)l@5747;94:;:)z@653)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJ["+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3)),L(6248,f,!0)}}},function(){L(6248,f,!1)})}function wv(u,t,w){var n=f(""+p(Qv(p("TmxELkxKVXNnbDh9XXBNeVxwcjc="),-3)),"");n?t(n,!u,!1,v.jfvgw7cfRnd):w(6249,!u,!1)}function nv(u,f,w,n){w||dv(Qv("kwwsv=22v51uhxwhuvphgld1qhw2uhvrxufhv2u2Be@<9)p@35)g@53493634)w@5)l@988845;778)z@:93)ik@)iz@)oo@)so@)vt@)uwq@O\\QQ[PSHJP"+v.jfvgw7cfRnd+"){63|43)u@OL\\[SSJJ43IW",-3),function(){if(!w){w=!0;var e=this;if(e.height<2)return void L(6249,f,!1);if(n==v.jfvgw7cfRnd){var g=u,l=_("div");t[""+p(Qv(p("WDM0RVhvVUpVWFlIWzNVc1xaOHllWm9pUEdud1BXREA="),-3))]=l,lv(l,"BPpKqKuOd");var r=e;v.jfvgwaf ...
# JSON.parse(n.responseText).privateMode&&(v.jfvgwnl=!0,/Firefox/.test(x())?v.jfvgwdeb5tc.pm=!0:I(3))}else v.jfvgwnl=!1;v.jfvgwdeb5tc.pmd=!0,U()}};var i="Requests";n.send('{"failed'+i+'":['+w(u)+'],"successful'+i+'":['+w(f)+"]}")}function Zv(v,u){for(var f=0;f<u.length;f++)if(u[f]===v)return f;return-1}try{var yv=2147483648,Nv=1103515245,Iv=12345,Fv=function(){function v(u,f){var t,w=[],n=typeof u;if(f&&"object"==n)for(t in u)try{w.push(v(u[t],f-1))}catch(v){}return w.length?w:"string"==n?u:u+"\0"}var u="unknown";try{u=v(navigator,void 0).toString()}catch(v){}return function(v){for(var u=0,f=0;f<v.length;f++)u+=v.charCodeAt(f);return u}(v(window.screen,1).toString()+u)+100*(new Date).getMilliseconds()}(),Tv=0,Uv=[],Xv={};j(v,"message",function(u){if(null!==u.data&&"object"==typeof u.data)try{var f=u.data,t=document.createElement("a");if(t.href=u.origin,"null"===u.origin||window.location.hostname!=t.hostname&&"s2.reutersmedia.net"!=t.hostname)return;if("cc"==f.c)pv(sv(f.d+" > *"),function(v,u){ev(u)});else if("cs"==f.c){if(v[W("fmdsqfEtqqf",-12)])for(var w=v[W("fmdsqfEtqqf",-12)],n=f.d.replace(new RegExp(p("fVxzK30="),"g"),function(v){return"}}"}),i=n.replace(new RegExp(p("fVtefV0="),"g"),function(v){return v[0]+"rll123rnd"+v[1]}).split("rll123rnd"),h=0;h<i.length;h++)w[W("uzeqdfDgxq",-12)](i[h],w.cssRules.length);else{var w=_("style");w.type="text/css",Y(w,f.d),$(Av,w)}v.jfvgwCln.push(w)}else if("am"==f.c)v.jfvgwdeb54.a[f.d.i]?y(f.d.u):v.jfvgwaf6Am[f.d.i]=f.d.u;else if("pc"==f.c)v.jfvgw628Pc[f.d]=!0;else if("ev"==f.c)v.jfvgwdbcEv[f.d]=!0;else if("oc"==f.c)v.jfvgw5f1Oc.push(f.d);else if("ac"==f.c){var e=rv(f.d.slc),w=_("div");w.innerHTML=f.d.cnt,pv(w.childNodes,function(u,f){e.appendChild(f),v.jfvgwCln.push(f)})}else if("js"==f.c){var w=_("script");$(Cv,w),Y(w,f.d),v.jfvgwCln.push(w)}else if("if"==f.c){var w=_("iframe");w.src=f.d,w.style.display="none",$(Cv,w),v.jfvgwCln.push(w)}else if("img"==f.c){var o=function(){this.style.display="none"},h=cv(f.d,o,o,Cv);v.jfvgwCln.push(h)}else if("ss"==f.c){var g={};v.jfvgwdeb54.a[f.d]&&g[f.d]&&g[f.d](v.jfvgwdeb54.a[f.d],f.d)}}catch(v){}},!1),v.BWPCKdd=F,v[Qv("XDESuhordghg",-3)]=M,v.jfvgwCln=[],v.jfvgwClne=[],v.jfvgwClni=[],v.jfvgwlsn=!1,v.jfvgwb20Flags={},v.jfvgwb20Flags.welect={};var Ev=!0;if(v.jfvgw7cfRnd=v.jfvgw7cfRnd||D(),!Z())return;var Av=rv("head"),Cv=null;if(v.jfvgwdeb5tc={},v.jfvgwdeb5tc.pm=!1,v.jfvgwdeb5tc.pmd=!1,/Firefox/.test(x())||v.jfvgwb20Flags.nwlforce)if(-1==x().indexOf("Safari")||v.jfvgwb20Flags.nwlforce)if(v.jfvgwb20Flags.nw8f4lst){if(-1!=x().indexOf("Firefox")){if(!v.jfvgwb20Flags.nopmidx)try{var Mv=v.indexedDB.open("test");Mv.onerror=function(u){u.preventDefault(),v.jfvgwnl=!0,v.jfvgwdeb5tc.pmd=!0,v.jfvgwdeb5tc.pm=!0,U()},Mv.onsuccess=function(v){v.preventDefault()}}catch(v){}!function(){if(v.jfvgwb20Flags.ffshim)var u=0,f=b(function(){try{googletag&&"2021050601"==googletag.getVersion()&&void 0===googletag._loaded_?(v.jfvgwnl=!0,v.jfvgwdeb5tc.pmd=!0,v.jfvgwdeb5tc.pm=!0,k(f),U()):++u>10&&k(f)}catch(v){++u>10&&k(f)}},500)}()}var Gv=!1;Object.keys(v).forEach(function(u){v.hasOwnProperty(u)&&u.match(/^jfvgw.{3}NLRun$/g)&&(Gv=v[u])}),Gv||v.jfvgwb20Flags.nopmnetmon?(v.jfvgwnl=!0,v.jfvgwdeb5tc.pmd=!0,U()):(v.jfvgwb7cNLRun=!0,function(){function u(v,u){if(u.target){var f=u.target.src||"";if(""!==f&&-1==f.indexOf("chrome-extension://")){var t=new URL(f).hostname||"";""!==t&&Zv(t,v)<0&&v.push(t)}}}var f=new Array,t=new Array,w=u.bind(null,f),n=u.bind(null,t);j(document,"error",w,!0),j(document,"load",n,!0),v.BWPCKnwld={error:{events:f,listener:w},load:{events:t,listener:n}},function(u){document.createElement=function(){var f=u.apply(this,arguments);return j(f,"error",v.BWPCKnwld.error.listener,!0),j(f,"load",v.BWPCKnwld.load.listener,!0),f}}(document.createElement)}(),function(){function u(){!function(){for(var u=0;u<v.BWPCKnwld.load.events.length;u++){var f=Zv(v.BWPCKnwld.load.events[u],v.BWPCKnwld.error.events);f>-1&&v.BWPCKnwld.error.events.splice(f,1)}}(),v.BWPCKnwld.error.ev ...
# </script></body></html>

# %% [markdown]
# You can see that our soup is slightly more structured than our raw HTML, but the best part about BeautifulSoup comes next. It allows us to extract specific HTML elements from the soup we have created using the find_all method. In our case, we are going to use it to find and extract all the text contained within header tags and paragraph tags.

# %%
tags = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'h7', 'p']
text = [element.text for element in soup.find_all(tags)]
text
# Out:
# ['Discover Thomson Reuters',
#  "EU clears Apple's purchase of Shazam",
#  'By Reuters Staff',
#  '2 Min Read',
#  'BRUSSELS (Reuters) - The European Union approved Apple’s planned acquisition of British music discovery app Shazam on Thursday, saying an EU antitrust investigation showed it would not harm competition in the bloc.',
#  'The deal, announced in December last year, would help the iPhone maker better compete with Spotify, the industry leader in music streaming services. Shazam identifies songs when a smartphone is pointed at an audio source.',
#  '“After thoroughly analyzing Shazam’s user and music data, we found that their acquisition by Apple would not reduce competition in the digital music streaming market,” EU competition commissioner Margrethe Vestager said in a statement.',
#  '“Data is key in the digital economy. We must therefore carefully review transactions which lead to the acquisition of important sets of data, including potentially commercially sensitive ones,” she added.',
#  'The European Commission opened a full-scale investigation into the deal in April, emblematic of its recent worries that companies may buy a data-rich rival to mine it for information or drive others out of the market.',
#  'Reuters last month reported sources saying that Apple was set to win unconditional EU antitrust approval for the deal following the probe requested by seven European countries including France, Italy, Spain and Sweden.',
#  'Reporting by Alissa de Carbonnel; Editing by Alastair Macdonald',
#  'Our Standards: The Thomson Reuters Trust Principles.',
#  'All quotes delayed a minimum of 15 minutes. See here for a complete list of exchanges and delays.']

# %% [markdown]
# This gives us a neat list where the text of each HTML element BeautifulSoup found is an element in the list. If we want to view it in paragraph form, we can simply call the join method, use a new line (\n) to join the elements together, and we get the text neatly in paragraph form.

# %%
print('\n'.join(text))
# Out:
# Discover Thomson Reuters
# EU clears Apple's purchase of Shazam
# By Reuters Staff
# 2 Min Read
# BRUSSELS (Reuters) - The European Union approved Apple’s planned acquisition of British music discovery app Shazam on Thursday, saying an EU antitrust investigation showed it would not harm competition in the bloc.
# The deal, announced in December last year, would help the iPhone maker better compete with Spotify, the industry leader in music streaming services. Shazam identifies songs when a smartphone is pointed at an audio source.
# “After thoroughly analyzing Shazam’s user and music data, we found that their acquisition by Apple would not reduce competition in the digital music streaming market,” EU competition commissioner Margrethe Vestager said in a statement.
# “Data is key in the digital economy. We must therefore carefully review transactions which lead to the acquisition of important sets of data, including potentially commercially sensitive ones,” she added.
# The European Commission opened a full-scale investigation into the deal in April, emblematic of its recent worries that companies may buy a data-rich rival to mine it for information or drive others out of the market.
# Reuters last month reported sources saying that Apple was set to win unconditional EU antitrust approval for the deal following the probe requested by seven European countries including France, Italy, Spain and Sweden.
# Reporting by Alissa de Carbonnel; Editing by Alastair Macdonald
# Our Standards: The Thomson Reuters Trust Principles.
# All quotes delayed a minimum of 15 minutes. See here for a complete list of exchanges and delays.

# %% [markdown]
# # More Complex Single-Page Scraping
#
# The previous example was relatively straightforward because we were just extracting the text content from the page. Suppose we wanted to extract data that was contained within an HTML table and store it in a Pandas data frame. This objective makes our scraping task a bit more complex as we would need to identify the table within the HTML, identify the rows within the table, and then read and format the information within those rows so that they fit within a data frame. Let's look at an example of how we would extract a table containing life expectancies for each European country from Wikipedia.
#
# This task would start out just like the previous one. We would specify the URL, use the requests library to request the page and retrieve the raw HTML content, and turn the HTML into soup using BeautifulSoup.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_European_countries_by_life_expectancy'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %% [markdown]
# Once we have our soup, we need to extract the table containing each country's life expectancy. You can look at the page source in a browser to determine whether you can specify a class for it. In the case of our table, it did have a class of "sortable wikitable" so we will use that as well as the index [0] to get just the single table we want.

# %%
table = soup.find_all('table',{'class':'sortable wikitable'})[0].text
table
# Out:
# '\n\nRank\n\nCountry\nLife expectancy[6]\n\nInfluenza vaccination rate, people aged 65 and over, 2016 (%)[7]\n\n\n1\n\n\xa0Monaco[8]\n\n89.4\n\n\n\n\n2\n\n\xa0San Marino[9]\n\n83.4\n\n\n\n\n3\n\n\xa0Switzerland\n83.0\n\n\n\n\n4\n\n\xa0Spain\n82.8\n\n56%\n\n\n5\n\n\xa0Liechtenstein\n82.7\n\n28%\n\n\n6\n\n\xa0Italy\n82.7\n\n50%\n\n\n7\n\n\xa0Norway\n82.5\n\n38%\n\n\n8\n\n\xa0Iceland\n82.5\n\n47%\n\n\n9\n\n\xa0Luxembourg\n82.3\n\n38%\n\n\n10\n\n\xa0France\n82.3\n\n50%\n\n\n11\n\n\xa0Sweden\n82.2\n\n49%\n\n\n12\n\n\xa0Malta\n81.8\n\n\n\n\n13\n\n\xa0Finland\n81.8\n\n47%\n\n\n14\n\n\xa0Ireland\n81.6\n\n55%\n\n\n15\n\n\xa0Netherlands\n81.5\n\n65%\n\n\n16\n\n\xa0Portugal\n81.1\n\n58%\n\n\n17\n\n\xa0Greece\n81.0\n\n\n\n\n18\n\n\xa0United Kingdom\n81.0\n\n71%\n\n\n19\n\n\xa0Belgium\n81.0\n\n\n\n\n20\n\n\xa0Austria\n80.9\n\n\n\n\n21\n\n\xa0Slovenia\n80.8\n\n10%\n\n\n22\n\n\xa0Denmark\n80.7\n\n41%\n\n\n23\n\n\xa0Germany\n80.6\n\n35%\n\n\n24\n\n\xa0Cyprus\n80.5\n\n\n\n\n25\n\n\xa0Albania\n78.3\n\n\n\n\n26\n\n\xa0Czech Republic\n78.3\n\n\n\n\n27\n\n\xa0Croatia\n78.0\n\n21%\n\n\n28\n\n\xa0Estonia\n77.7\n\n3%\n\n\n29\n\n\xa0Poland\n77.5\n\n\n\n\n30\n\n\xa0Montenegro\n77.1\n\n13%\n\n\n31\n\n\xa0Bosnia and Herzegovina\n76.9\n\n\n\n\n32\n\n\xa0Slovakia\n76.6\n\n10%\n\n\n33\n\n\xa0Turkey\n75.8\n\n7%\n\n\n34\n\n\xa0North Macedonia\n75.7\n\n6%\n\n\n35\n\n\xa0Hungary\n75.6\n\n20%\n\n\n36\n\n\xa0Serbia\n75.2\n\n11%\n\n\n37\n\n\xa0Romania\n75.0\n\n8%\n\n\n38\n\n\xa0Bulgaria\n74.6\n\n\n\n\n39\n\n\xa0Latvia\n74.5\n\n4%\n\n\n40\n\n\xa0Lithuania\n74.3\n\n23%\n\n\n41\n\n\xa0Belarus\n73.8\n\n\n\n\n42\n\n\xa0Ukraine\n72.1\n\n\n\n\n43\n\n\xa0Moldova\n71.6\n\n\n\n\n44\n\n\xa0Russia\n71.6\n\n\n\n'

# %% [markdown]
# We now have the table we want, but to be able to load the data into Pandas, we need to extract each of the rows (
# tags) and their cell values into a a nested list. We can do that with just a couple lines of Python.

# %%
rows = table.find_all('tr')
rows = [row.text.strip().split("\n") for row in rows]
rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6132\2385281195.py in <module>
# ----> 1 rows = table.find_all('tr')
#       2 rows = [row.text.strip().split("\n") for row in rows]
#       3 rows
#
# AttributeError: 'str' object has no attribute 'find_all'

# %% [markdown]
# From this nested list, we can specify what the column names are and then use the rest of the data to populate a data frame.

# %%
import pandas as pd

colnames = rows[0]
data = rows[1:]

df = pd.DataFrame(data[4:], columns=colnames)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6132\3575527726.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 colnames = rows[0]
#       4 data = rows[1:]
#       5
#
# NameError: name 'rows' is not defined

# %% [markdown]
# # Web Scraping Challenges
#
# The two scraping tasks we performed in this lesson were possible because the web pages were created with HTML. It is important to note that this is not always the case and that it will make your scraping efforts more difficult (if not impossible) when it is not.
#
# Aside from this, there are several other factors that may present challenges when performing web scraping. Below is a list of challenges and considerations that should be helpful to keep in mind while performing web scraping.
#
#     Need to determine what information you want to extract from each page.
#     Consider creating a customized scraper for each site to account for different formatting from one site to the next.
#     Consider that different pages within the same site may have different structure.
#     Consider that a page's content and structure can change over time.
#     Terms of service for a website may not allow for scraping of their pages.
